# %% [markdown]
# **0.SETUP**

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("pkdarabi/bone-fracture-detection-computer-vision-project")

print("Path to dataset files:", path)
# Out:
# Using Colab cache for faster access to the 'bone-fracture-detection-computer-vision-project' dataset.
# Path to dataset files: /kaggle/input/bone-fracture-detection-computer-vision-project

# %% [markdown]
# ## 0.1 Connecting to google drive so my work persists

# %%
from google.colab import drive
drive.mount('/content/drive')

import os
PROJECT_DIR = '/content/drive/MyDrive/bone-fracture-detection'
os.makedirs(PROJECT_DIR, exist_ok=True)
os.chdir(PROJECT_DIR)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ## 0.2 Inspecting the folders in my dataset

# %%
import os

for root, dirs, files in os.walk(path):
    level = root.replace(path, '').count(os.sep)
    indent = '  ' * level
    print(f'{indent}{os.path.basename(root) or root}/')
    if level < 2:
        for f in files[:5]:
            print(f'{indent}  {f}')
# Out:
# bone-fracture-detection-computer-vision-project/
#   bone fracture detection.v4-v4.yolov8/
#     README.dataset.txt
#     data.yaml
#     valid/
#       labels/
#       images/
#     test/
#       labels/
#       images/
#     train/
#       labels/
#       images/
#   BoneFractureYolo8/
#     README.dataset.txt
#     data.yaml
#     valid/
#       labels/
#       images/
#     test/
#       labels/
#       images/
#     train/
#       labels/
#       images/

# %% [markdown]
# ## 0.3 Setting up the folder structure

# %%
folders = [
    'src/bonefracture',
    'datasets',
    'metrics',
    'models',
    'test'

]
for f in folders:
    os.makedirs(f, exist_ok=True)

open('src/bonefracture/__init__.py', 'a').close()

for f in ['data_processing.py', 'train.py', 'evaluate.py', 'inference.py']:
  open(f'src/bonefracture/{f}', 'a').close()

print("Structure created: ")
# !find . -not -path '*/.git*' -maxdepth 3 | sort
# Out:
# Structure created:
# find: warning: you have specified the global option -maxdepth after the argument -not, but global options are not positional, i.e., -maxdepth affects tests specified before it as well as those specified after it.  Please specify global options before other arguments.
# .
# ./datasets
# ./metrics
# ./models
# ./requirements.txt
# ./src
# ./src/bonefracture
# ./src/bonefracture/data_processing.py
# ./src/bonefracture/evaluate.py
# ./src/bonefracture/inference.py
# ./src/bonefracture/__init__.py
# ./src/bonefracture/train.py
# ./test

# %% [markdown]
# ## 0.4 .gitignore and a requirements.txt for GitHub

# %%
# %%writefile .gitignore
# data/
# models/
# *.pt
# *.pth
# __pycache__/
# *.pyc
# .ipynb_checkpoints/
# .env
# Out:
# Overwriting .gitignore

# %%
# %%writefile requirements.txt
# kagglehub
# ultralytics
# torch
# torchvision
# mlflow
# pytest
# Out:
# Overwriting requirements.txt

# %%
from google.colab import userdata

token = userdata.get('GITHUB_TOKEN')
username = "baotle"
repo_name = "BoneFractureDetection_Computervision_Project"
remote_url = f"https://{token}@github.com/{username}/{repo_name}.git"

# !git init
# !git add .
# !git commit -m "Initial project structure"
# !git branch -M main
# !git remote remove origin
# !git remote add origin {remote_url}
# !git push -u origin main -q
# Out:
# Reinitialized existing Git repository in /content/drive/MyDrive/bone-fracture-detection/.git/
# On branch main
# nothing to commit, working tree clean
# To https://github.com/baotle/BoneFractureDetection_Computervision_Project.git
#  ! [rejected]        main -> main (fetch first)
# error: failed to push some refs to 'https://github.com/baotle/BoneFractureDetection_Computervision_Project.git'
# hint: Updates were rejected because the remote contains work that you do
# hint: not have locally. This is usually caused by another repository pushing
# hint: to the same ref. You may want to first integrate the remote changes
# hint: (e.g., 'git pull ...') before pushing again.
# hint: See the 'Note about fast-forwards' in 'git push --help' for details.

# %%
# !git pull origin main --allow-unrelated-histories
# Out:
# remote: Enumerating objects: 3, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Compressing objects: 100% (2/2), done.
# remote: Total 3 (delta 0), reused 0 (delta 0), pack-reused 0 (from 0)
# Unpacking objects: 100% (3/3), 1.44 KiB | 35.00 KiB/s, done.
# From https://github.com/baotle/BoneFractureDetection_Computervision_Project
#  * branch            main       -> FETCH_HEAD
#  * [new branch]      main       -> origin/main
# hint: You have divergent branches and need to specify how to reconcile them.
# hint: You can do so by running one of the following commands sometime before
# hint: your next pull:
# hint:
# hint:   git config pull.rebase false  # merge (the default strategy)
# hint:   git config pull.rebase true   # rebase
# hint:   git config pull.ff only       # fast-forward only
# hint:
# hint: You can replace "git config" with "git config --global" to set a default
# hint: preference for all repositories. You can also pass --rebase, --no-rebase,
# hint: or --ff-only on the command line to override the configured default per
# hint: invocation.
# fatal: Need to specify how to reconcile divergent branches.

# %%
# !git push -u origin main -q
# Out:
# To https://github.com/baotle/BoneFractureDetection_Computervision_Project.git
#  ! [rejected]        main -> main (non-fast-forward)
# error: failed to push some refs to 'https://github.com/baotle/BoneFractureDetection_Computervision_Project.git'
# hint: Updates were rejected because the tip of your current branch is behind
# hint: its remote counterpart. Integrate the remote changes (e.g.
# hint: 'git pull ...') before pushing again.
# hint: See the 'Note about fast-forwards' in 'git push --help' for details.

# %%
# !git status
# Out:
# On branch main
# nothing to commit, working tree clean

# %%
# !git log --oneline --graph --all -10
# Out:
# * 3b3726f (HEAD -> main) Initial project structure
# * 9b54309 (origin/main) Initial commit

# %%
# !git pull origin main --allow-unrelated-histories --no-edit
# Out:
# From https://github.com/baotle/BoneFractureDetection_Computervision_Project
#  * branch            main       -> FETCH_HEAD
# hint: You have divergent branches and need to specify how to reconcile them.
# hint: You can do so by running one of the following commands sometime before
# hint: your next pull:
# hint:
# hint:   git config pull.rebase false  # merge (the default strategy)
# hint:   git config pull.rebase true   # rebase
# hint:   git config pull.ff only       # fast-forward only
# hint:
# hint: You can replace "git config" with "git config --global" to set a default
# hint: preference for all repositories. You can also pass --rebase, --no-rebase,
# hint: or --ff-only on the command line to override the configured default per
# hint: invocation.
# fatal: Need to specify how to reconcile divergent branches.

# %%
# !git log --oneline --graph --all -10
# Out:
# * 3b3726f (HEAD -> main) Initial project structure
# * 9b54309 (origin/main) Initial commit

# %%
# !git pull origin main --allow-unrelated-histories --no-edit
# Out:
# From https://github.com/baotle/BoneFractureDetection_Computervision_Project
#  * branch            main       -> FETCH_HEAD
# hint: You have divergent branches and need to specify how to reconcile them.
# hint: You can do so by running one of the following commands sometime before
# hint: your next pull:
# hint:
# hint:   git config pull.rebase false  # merge (the default strategy)
# hint:   git config pull.rebase true   # rebase
# hint:   git config pull.ff only       # fast-forward only
# hint:
# hint: You can replace "git config" with "git config --global" to set a default
# hint: preference for all repositories. You can also pass --rebase, --no-rebase,
# hint: or --ff-only on the command line to override the configured default per
# hint: invocation.
# fatal: Need to specify how to reconcile divergent branches.

# %%
# !git pull origin main --allow-unrelated-histories --no-rebase --no-edit
# Out:
# From https://github.com/baotle/BoneFractureDetection_Computervision_Project
#  * branch            main       -> FETCH_HEAD
# Merge made by the 'ort' strategy.
#  LICENSE | 21 +++++++++++++++++++++
#  1 file changed, 21 insertions(+)
#  create mode 100644 LICENSE

# %%
# !git log --oneline --graph --all -10
# Out:
# *   41670d2 (HEAD -> main) Merge branch 'main' of https://github.com/baotle/BoneFractureDetection_Computervision_Project
# |\
# | * 9b54309 (origin/main) Initial commit
# * 3b3726f Initial project structure

# %%
# !git push -u origin main -q

# %%
# !mkdir -p notebooks
# !git mv bonefracture-main.ipynb notebooks/00_setup_and_exploration.ipynb
# Out:
# fatal: not a git repository (or any of the parent directories): .git
